# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('NBA.csv')

# %%
plt.pie(data['points/game'],labels = data['player'], autopct = '%.0f%%', explode = [0,0,0.2,0,0])
plt.title('NBA player scores', size = 20)
plt.show()
